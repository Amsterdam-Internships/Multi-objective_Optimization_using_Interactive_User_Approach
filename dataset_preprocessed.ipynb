# %%
import pandas as pd
import numpy as np
from numpy.random import RandomState
from scipy.stats import norm
import geopandas as gpd
import copy
import sys
sys.path.insert(0, 'D:/modules/thesis/resources/gp_pref_elicit/gp_utilities/utils_data')

# %%
# original (shortened) dataset
# to use actual (large) dataset, uncomment the below line:
# sidewalk = gpd.read_file('data\Sidewalk_width_crossings.geojson')
sidewalk = gpd.read_file('data\Sidewalk_width_crossings_small.geojson')
sidewalk
# Out:
#         id  0.9-1.8m  1.8-2.9m  <0.9m  >2.9m  crossing  length  \
# 0        0         0         0      0      1         0    9.99
# 1        1         0         0      0      1         0    3.64
# 2        2         1         0      0      0         0    4.30
# 3        3         1         0      0      0         0    3.20
# 4        4         0         0      0      0         0    9.99
# ...    ...       ...       ...    ...    ...       ...     ...
# 1134  1134         0         0      0      1         1    8.41
# 1135  1135         0         0      0      1         1   25.81
# 1136  1136         0         0      0      1         1    9.47
# 1137  1137         0         0      0      1         1    8.41
# 1138  1138         0         0      0      1         1   10.14
#
#      obstacle_free_width  unknown  \
# 0                  >2.9m        0
# 1                  >2.9m        0
# 2               0.9-1.8m        0
# 3               0.9-1.8m        0
# 4                unknown        1
# ...                  ...      ...
# 1134               >2.9m        0
# 1135               >2.9m        0
# 1136               >2.9m        0
# 1137               >2.9m        0
# 1138               >2.9m        0
#
#                                                geometry
# 0     LINESTRING (120548.61203 486088.19578, 120548....
# 1     LINESTRING (120558.58273 486088.59136, 120558....
# 2     LINESTRING (120554.77791 486105.08163, 120555....
# 3     LINESTRING (120561.12010 486102.03679, 120561....
# 4     LINESTRING (120549.11715 486040.41439, 120549....
# ...                                                 ...
# 1134  LINESTRING (120971.41298 485981.36204, 120971....
# 1135  LINESTRING (120916.43844 486032.00808, 120890....
# 1136  LINESTRING (120940.10969 486013.85196, 120940....
# 1137  LINESTRING (120971.64289 485989.76706, 120971....
# 1138  LINESTRING (121022.96280 485775.15360, 121015....
#
# [1139 rows x 10 columns]

# %%
# dataset with only columns that are needed 
dataset1 = sidewalk[['0.9-1.8m', '1.8-2.9m', '<0.9m', '>2.9m', 'crossing', 'length', 'obstacle_free_width', 'unknown']].copy()
dataset1
# Out:
#       0.9-1.8m  1.8-2.9m  <0.9m  >2.9m  crossing  length obstacle_free_width  \
# 0            0         0      0      1         0    9.99               >2.9m
# 1            0         0      0      1         0    3.64               >2.9m
# 2            1         0      0      0         0    4.30            0.9-1.8m
# 3            1         0      0      0         0    3.20            0.9-1.8m
# 4            0         0      0      0         0    9.99             unknown
# ...        ...       ...    ...    ...       ...     ...                 ...
# 1134         0         0      0      1         1    8.41               >2.9m
# 1135         0         0      0      1         1   25.81               >2.9m
# 1136         0         0      0      1         1    9.47               >2.9m
# 1137         0         0      0      1         1    8.41               >2.9m
# 1138         0         0      0      1         1   10.14               >2.9m
#
#       unknown
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# ...       ...
# 1134        0
# 1135        0
# 1136        0
# 1137        0
# 1138        0
#
# [1139 rows x 8 columns]

# %%
# multiplying all columns with the value in the length column as we are going towards six objectives
# columns '0.9-1.8m', '1.8-2.9m', '<0.9m', '>2.9m' and 'unknown' are path lengths of respective widths
boolean_columns = ['0.9-1.8m', '1.8-2.9m', '<0.9m', '>2.9m', 'unknown']
dataset1[boolean_columns] = dataset1[boolean_columns].mul(dataset1['length'], axis = 0)
dataset1
# Out:
#       0.9-1.8m  1.8-2.9m  <0.9m  >2.9m  crossing  length obstacle_free_width  \
# 0          0.0       0.0    0.0   9.99         0    9.99               >2.9m
# 1          0.0       0.0    0.0   3.64         0    3.64               >2.9m
# 2          4.3       0.0    0.0   0.00         0    4.30            0.9-1.8m
# 3          3.2       0.0    0.0   0.00         0    3.20            0.9-1.8m
# 4          0.0       0.0    0.0   0.00         0    9.99             unknown
# ...        ...       ...    ...    ...       ...     ...                 ...
# 1134       0.0       0.0    0.0   8.41         1    8.41               >2.9m
# 1135       0.0       0.0    0.0  25.81         1   25.81               >2.9m
# 1136       0.0       0.0    0.0   9.47         1    9.47               >2.9m
# 1137       0.0       0.0    0.0   8.41         1    8.41               >2.9m
# 1138       0.0       0.0    0.0  10.14         1   10.14               >2.9m
#
#       unknown
# 0        0.00
# 1        0.00
# 2        0.00
# 3        0.00
# 4        9.99
# ...       ...
# 1134     0.00
# 1135     0.00
# 1136     0.00
# 1137     0.00
# 1138     0.00
#
# [1139 rows x 8 columns]

# %%
# wherever the crossing column has a boolean 1, all the other widths have a value 0 as widths don't define the crossings
crossing_col = dataset1['crossing'] == 1
dataset1.loc[crossing_col, dataset1.columns != 'crossing'] = 0
dataset1
# Out:
#       0.9-1.8m  1.8-2.9m  <0.9m  >2.9m  crossing  length obstacle_free_width  \
# 0          0.0       0.0    0.0   9.99         0    9.99               >2.9m
# 1          0.0       0.0    0.0   3.64         0    3.64               >2.9m
# 2          4.3       0.0    0.0   0.00         0    4.30            0.9-1.8m
# 3          3.2       0.0    0.0   0.00         0    3.20            0.9-1.8m
# 4          0.0       0.0    0.0   0.00         0    9.99             unknown
# ...        ...       ...    ...    ...       ...     ...                 ...
# 1134       0.0       0.0    0.0   0.00         1    0.00                   0
# 1135       0.0       0.0    0.0   0.00         1    0.00                   0
# 1136       0.0       0.0    0.0   0.00         1    0.00                   0
# 1137       0.0       0.0    0.0   0.00         1    0.00                   0
# 1138       0.0       0.0    0.0   0.00         1    0.00                   0
#
#       unknown
# 0        0.00
# 1        0.00
# 2        0.00
# 3        0.00
# 4        9.99
# ...       ...
# 1134     0.00
# 1135     0.00
# 1136     0.00
# 1137     0.00
# 1138     0.00
#
# [1139 rows x 8 columns]

# %%
# dropping the length column as we have its values multiplied with other columns, so we have 6 objectives instead of 7
new_dataset = dataset1.drop('length', axis=1)
new_dataset
# Out:
#       0.9-1.8m  1.8-2.9m  <0.9m  >2.9m  crossing obstacle_free_width  unknown
# 0          0.0       0.0    0.0   9.99         0               >2.9m     0.00
# 1          0.0       0.0    0.0   3.64         0               >2.9m     0.00
# 2          4.3       0.0    0.0   0.00         0            0.9-1.8m     0.00
# 3          3.2       0.0    0.0   0.00         0            0.9-1.8m     0.00
# 4          0.0       0.0    0.0   0.00         0             unknown     9.99
# ...        ...       ...    ...    ...       ...                 ...      ...
# 1134       0.0       0.0    0.0   0.00         1                   0     0.00
# 1135       0.0       0.0    0.0   0.00         1                   0     0.00
# 1136       0.0       0.0    0.0   0.00         1                   0     0.00
# 1137       0.0       0.0    0.0   0.00         1                   0     0.00
# 1138       0.0       0.0    0.0   0.00         1                   0     0.00
#
# [1139 rows x 7 columns]

# %%
new_dataset['obstacle_free_width'].unique()
# Out:
# array(['>2.9m', '0.9-1.8m', 'unknown', '1.8-2.9m', '<0.9m', 0],
#       dtype=object)

# %%
new_dataset['obstacle_free_width'].value_counts()
# Out:
# >2.9m       324
# 1.8-2.9m    277
# unknown     180
# 0           174
# 0.9-1.8m    141
# <0.9m        43
# Name: obstacle_free_width, dtype: int64

# %%
categorize_obstacles = {"obstacle_free_width": {'0':0, '0.9-1.8m':1, '1.8-2.9m':2, '<0.9m':3,'>2.9m':4,'unknown':5}}
new_dataset = new_dataset.replace(categorize_obstacles)
new_dataset
# Out:
#       0.9-1.8m  1.8-2.9m  <0.9m  >2.9m  crossing  obstacle_free_width  unknown
# 0          0.0       0.0    0.0   9.99         0                    4     0.00
# 1          0.0       0.0    0.0   3.64         0                    4     0.00
# 2          4.3       0.0    0.0   0.00         0                    1     0.00
# 3          3.2       0.0    0.0   0.00         0                    1     0.00
# 4          0.0       0.0    0.0   0.00         0                    5     9.99
# ...        ...       ...    ...    ...       ...                  ...      ...
# 1134       0.0       0.0    0.0   0.00         1                    0     0.00
# 1135       0.0       0.0    0.0   0.00         1                    0     0.00
# 1136       0.0       0.0    0.0   0.00         1                    0     0.00
# 1137       0.0       0.0    0.0   0.00         1                    0     0.00
# 1138       0.0       0.0    0.0   0.00         1                    0     0.00
#
# [1139 rows x 7 columns]
