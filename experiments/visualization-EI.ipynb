# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import csv

# %%
data = pd.read_csv('output-EI_7-100.csv')

# %%
num_queries = data['Number of Queries']
regret = data['Regret']

# %%
# regret = [float(value[1:-1]) for value in regret]
regret_vals = np.array([regret[0] for regret in regret])
# regret_round = np.round(regret, 3)

# %%
# data = []
# with open('output-EI_5-100.csv', 'r') as csvf:
#     read = csv.reader(csvf)
#     next(read)
#     for row in read:
#         data.append(row)

# num_queries = data['Num']
# regret = [float(row[1]) for row in data]

# %%
df = pd.DataFrame({'Number of Queries': num_queries, 'Regret': regret_vals})
sns.histplot(data=df, x='Number of Queries', bins=50, stat='count', alpha=0.8)
# stat is the aggregate statistic to compute in each bin. Stat is chosen to be count to show the 
# number of observations in each bin
plt.xlabel('Number of Queries')
plt.ylabel('Count')
plt.title('Distribution of Number of Queries as a function of the Regret')
plt.show()

# %%
data1 = pd.read_csv('experiments/regret-EI_5-100.csv')
regret_vals_1 = np.array([regret[0] for regret in regret])
df1 = pd.DataFrame({'Step': data['Step'], 'Regret': regret_vals_1})
sns.histplot(data=df, x='Step', bins=50, stat='count', alpha=0.8)
# stat is the aggregate statistic to compute in each bin. Stat is chosen to be count to show the 
# number of observations in each bin
plt.xlabel('Number of Queries')
plt.ylabel('Count')
plt.title('Distribution of Number of Queries as a function of the Regret')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data1 = pd.read_csv('experiments/regret-EI_5-100.csv')
#       2 regret_vals_1 = np.array([regret[0] for regret in regret])
#       3 df1 = pd.DataFrame({'Step': data['Step'], 'Regret': regret_vals_1})
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
plt.hist(x=num_queries, bins=100, color='blue', alpha=0.5)
plt.show()
